# %%
import os

import pandas as pd
import numpy as np
import seaborn as snsm
import matplotlib.pyplot as plt
import seaborn as sns

import warnings; warnings.simplefilter('ignore')

# %%
os.chdir('Data2/')

# %% [markdown]
# # Combine Brews and Beers DFs

# %%
beer_df = pd.read_pickle('Clean_Beer_Data')

# %%
brews_df = pd.read_pickle('Clean_Brewery_Data')

# %%
df = pd.concat([beer_df, brews_df],axis=1,join='inner')

# %% [markdown]
# ### Taking a look at Correlations

# %%
corr_df = df.corr()

# %%
plt.figure(figsize=(26,22))
sns.heatmap(df_corr,cmap='viridis',annot=True)
plt.tight_layout;

# %% [markdown]
# That looks a little too busy.
# Let's reduce the number of rows and columns by filtering out any values with a correlation weaker than `abs(0.1)` and take another look.

# %%
reduced_corr_df = corr_df[abs(corr_df.Score) > .1]
reduced_corr_df = reduced_corr_df.transpose()
reduced_corr_df = reduced_corr_df[abs(corr_df.Score) > .1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-939b555143a7> in <module>()
#       2 reduced_corr_df = reduced_corr_df.transpose()
#       3 reduced_corr_df = reduced_corr_df[abs(corr_df.Score) > .1]
# ----> 4 reduced_corr_df.size()
#
# TypeError: 'numpy.int64' object is not callable

# %%
plt.figure(figsize=(26,22))
sns.heatmap(reduced_corr_df,
            cmap='viridis',annot=True)
plt.tight_layout;

# %% [markdown]
# ### Looking at Columns derived from Beer Style Categories
